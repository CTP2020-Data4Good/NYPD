# %%
import pandas as pd
pd.set_option('max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy.stats as stats
sns.set()

# %matplotlib inline 


# import sklearn
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, precision_score, recall_score, 
confusion_matrix, f1_score, roc_auc_score, make_scorer)
from sklearn.model_selection import GridSearchCV 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('data/allegations_202007271729.csv')
df.head().T
# Out:
#                                                                  0  \
# unique_mos_id                                                10004
# first_name                                                Jonathan
# last_name                                                     Ruiz
# command_now                                                078 PCT
# shield_no                                                     8409
# complaint_id                                                 42835
# month_received                                                   7
# year_received                                                 2019
# month_closed                                                     5
# year_closed                                                   2020
# command_at_incident                                        078 PCT
# rank_abbrev_incident                                           POM
# rank_abbrev_now                                                POM
# rank_now                                            Police Officer
# rank_incident                                       Police Officer
# mos_ethnicity                                             Hispanic
# mos_gender                                                       M
# mos_age_incident                                                32
# complainant_ethnicity                                        Black
# complainant_gender                                          Female
# complainant_age_incident                                        38
# fado_type                                       Abuse of Authority
# allegation                            Failure to provide RTKA card
# precinct                                                        78
# contact_reason                             Report-domestic dispute
# outcome_description               No arrest made or summons issued
# board_disposition         Substantiated (Command Lvl Instructions)
#
#                                                         1  \
# unique_mos_id                                       10007
# first_name                                           John
# last_name                                           Sears
# command_now                                       078 PCT
# shield_no                                            5952
# complaint_id                                        24601
# month_received                                         11
# year_received                                        2011
# month_closed                                            8
# year_closed                                          2012
# command_at_incident                                  PBBS
# rank_abbrev_incident                                  POM
# rank_abbrev_now                                       POM
# rank_now                                   Police Officer
# rank_incident                              Police Officer
# mos_ethnicity                                       White
# mos_gender                                              M
# mos_age_incident                                       24
# complainant_ethnicity                               Black
# complainant_gender                                   Male
# complainant_age_incident                               26
# fado_type                                     Discourtesy
# allegation                                         Action
# precinct                                               67
# contact_reason                           Moving violation
# outcome_description       Moving violation summons issued
# board_disposition                 Substantiated (Charges)
#
#                                                         2  \
# unique_mos_id                                       10007
# first_name                                           John
# last_name                                           Sears
# command_now                                       078 PCT
# shield_no                                            5952
# complaint_id                                        24601
# month_received                                         11
# year_received                                        2011
# month_closed                                            8
# year_closed                                          2012
# command_at_incident                                  PBBS
# rank_abbrev_incident                                  POM
# rank_abbrev_now                                       POM
# rank_now                                   Police Officer
# rank_incident                              Police Officer
# mos_ethnicity                                       White
# mos_gender                                              M
# mos_age_incident                                       24
# complainant_ethnicity                               Black
# complainant_gender                                   Male
# complainant_age_incident                               26
# fado_type                              Offensive Language
# allegation                                           Race
# precinct                                               67
# contact_reason                           Moving violation
# outcome_description       Moving violation summons issued
# board_disposition                 Substantiated (Charges)
#
#                                                                      3  \
# unique_mos_id                                                    10007
# first_name                                                        John
# last_name                                                        Sears
# command_now                                                    078 PCT
# shield_no                                                         5952
# complaint_id                                                     26146
# month_received                                                       7
# year_received                                                     2012
# month_closed                                                         9
# year_closed                                                       2013
# command_at_incident                                               PBBS
# rank_abbrev_incident                                               POM
# rank_abbrev_now                                                    POM
# rank_now                                                Police Officer
# rank_incident                                           Police Officer
# mos_ethnicity                                                    White
# mos_gender                                                           M
# mos_age_incident                                                    25
# complainant_ethnicity                                            Black
# complainant_gender                                                Male
# complainant_age_incident                                            45
# fado_type                                           Abuse of Authority
# allegation                                                    Question
# precinct                                                            67
# contact_reason            PD suspected C/V of violation/crime - street
# outcome_description                   No arrest made or summons issued
# board_disposition                              Substantiated (Charges)
#
#                                                              4
# unique_mos_id                                            10009
# first_name                                               Noemi
# last_name                                               Sierra
# command_now                                            078 PCT
# shield_no                                                24058
# complaint_id                                             40253
# month_received                                               8
# year_received                                             2018
# month_closed                                                 2
# year_closed                                               2019
# command_at_incident                                    078 PCT
# rank_abbrev_incident                                       POF
# rank_abbrev_now                                            POF
# rank_now                                        Police Officer
# rank_incident                                   Police Officer
# mos_ethnicity                                         Hispanic
# mos_gender                                                   F
# mos_age_incident                                            39
# complainant_ethnicity                                      NaN
# complainant_gender                                         NaN
# complainant_age_incident                                    16
# fado_type                                                Force
# allegation                                      Physical force
# precinct                                                    67
# contact_reason                                  Report-dispute
# outcome_description             Arrest - other violation/crime
# board_disposition         Substantiated (Command Discipline A)

# %%
df['contact_reason'].value_counts()
# Out:
# PD suspected C/V of violation/crime - street                  10078
# Other                                                          4104
# PD suspected C/V of violation/crime - auto                     2981
# PD suspected C/V of violation/crime - bldg                     2542
# Moving violation                                               1983
# Other violation of VTL                                         1140
# Report-dispute                                                 1085
# Execution of search warrant                                     913
# Report of other crime                                           906
# Execution of arrest/bench warrant                               683
# Parking violation                                               635
# Report-domestic dispute                                         563
# C/V intervened on behalf of/observed encounter w/3rd party      540
# Report-gun possession/shots fired                               492
# PD suspected C/V of violation/crime - subway                    380
# Patrol Encounter                                                362
# Report-noise/disturbance                                        356
# Report-possession/sale of narcotics                             318
# C/V requested investigation of crime                            316
# EDP aided case                                                  313
# Traffic Incidents/Accident/Prk Violation                        219
# Stop/Question/Frisk                                             206
# Traffic accident                                                200
# Others                                                          189
# C/V telephoned PCT                                              175
# C/V at PCT to obtain information                                167
# Report of Crime Past/Present                                    165
# Aided case                                                      154
# C/V requested info from officer                                 112
# Dispute                                                         104
# C/V at PCT to file complaint of crime                           102
# CV already in custody                                           100
# Arrest/Complainant                                               73
# Vehicle Stop and Check                                           51
# Arrest/Not Complainant                                           46
# Parade/special event                                             46
# C/V at PCT to retrieve property                                  40
# PD auto checkpoint                                               39
# Summons/Complainant                                              39
# Assist ACS or other agency                                       39
# Regulatory inspection                                            36
# Report of Disturbance/Noise Complaint                            36
# Demonstration/protest                                            35
# PD telephones CV                                                 18
# Complainant at Pct. to make a Cmpl/info                          16
# EDP Aided Cases                                                  12
# Telephone Call to Precinct/Command                               11
# Transit checkpoint                                               11
# Aided Cases                                                      10
# Demonstrations                                                    8
# Complainant Witnessing Incident                                   5
# No contact                                                        3
# Victim Subject of Sex Crime                                       2
# Name: contact_reason, dtype: int64

# %%
df['allegation'].value_counts()
# Out:
# Physical force                   4849
# Word                             3942
# Stop                             2300
# Search (of person)               2047
# Frisk                            1926
#                                  ...
# Jewish                              2
# Questioned immigration status       1
# Other Asian                         1
# Sexist Remark                       1
# Oriental                            1
# Name: allegation, Length: 115, dtype: int64

# %%
df.isna().sum()
# Out:
# unique_mos_id                  0
# first_name                     0
# last_name                      0
# command_now                    0
# shield_no                      0
# complaint_id                   0
# month_received                 0
# year_received                  0
# month_closed                   0
# year_closed                    0
# command_at_incident         1544
# rank_abbrev_incident           0
# rank_abbrev_now                0
# rank_now                       0
# rank_incident                  0
# mos_ethnicity                  0
# mos_gender                     0
# mos_age_incident               0
# complainant_ethnicity       4464
# complainant_gender          4195
# complainant_age_incident    4812
# fado_type                      0
# allegation                     1
# precinct                      24
# contact_reason               199
# outcome_description           56
# board_disposition              0
# dtype: int64

# %%
df['rank_incident'].value_counts()
# Out:
# Police Officer            22509
# Sergeant                   5934
# Detective                  3307
# Lieutenant                 1301
# Captain                     182
# Deputy Inspector             96
# Inspector                    27
# Chiefs and other ranks        2
# Name: rank_incident, dtype: int64

# %%
df['unique_mos_id'].value_counts()
# Out:
# 25861    75
# 18731    75
# 19489    73
# 18530    73
# 18589    72
#          ..
# 11517     1
# 26350     1
# 22637     1
# 22280     1
# 5334      1
# Name: unique_mos_id, Length: 3996, dtype: int64

# %%
df['outcome_description'].value_counts()
# Out:
# No arrest made or summons issued        12822
# Arrest - other violation/crime          10196
# Summons - disorderly conduct             2118
# Summons - other violation/crime          1940
# Arrest - resisting arrest                1593
# Arrest - disorderly conduct              1013
# Arrest - assault (against a PO)           852
# Moving violation summons issued           839
# Arrest - OGA                              649
# Other VTL violation summons issued        531
# Parking summons issued                    279
# Disorderly-Conduct/Arr/Summons            137
# Arrest on Other Charge                     81
# Traffic Summons Claimed or Issued          59
# Juvenile Report                            57
# Other Summons Claimed or Issued            38
# Assault/Arrested                           34
# Resisting Arrest/Arrested                  25
# Arrest - harrassment (against a PO)        15
# Obstruct-Govt-Admin/Arrested               10
# Harrassment/Arrested/Summons                8
# Summons - harrassment (against a PO)        5
# Summons - OGA                               1
# Name: outcome_description, dtype: int64

# %%
df['board_disposition'].value_counts()
# Out:
# Unsubstantiated                             15448
# Exonerated                                   9609
# Substantiated (Charges)                      3796
# Substantiated (Formalized Training)          1033
# Substantiated (Command Discipline A)          964
# Substantiated (Command Discipline)            851
# Substantiated (Command Discipline B)          789
# Substantiated (Command Lvl Instructions)      454
# Substantiated (Instructions)                  248
# Substantiated (No Recommendations)            165
# Substantiated (MOS Unidentified)                1
# Name: board_disposition, dtype: int64

# %% [markdown]
# ## Drop columns that will not be useful for model
# Not going to use `first_name`, `shiedl_no`, `last_name`, `rank_now`, `rank_incident`. Removing the last two because they're redundant and rank_abbrev have more detail.

# %%
df.drop(['first_name', 'last_name', 'rank_incident', 'rank_now', 'shield_no'], axis=1, inplace=True)

# %%
#Sanity check for modified df
df.head().T
# Out:
#                                                                  0  \
# unique_mos_id                                                10004
# command_now                                                078 PCT
# complaint_id                                                 42835
# month_received                                                   7
# year_received                                                 2019
# month_closed                                                     5
# year_closed                                                   2020
# command_at_incident                                        078 PCT
# rank_abbrev_incident                                           POM
# rank_abbrev_now                                                POM
# mos_ethnicity                                             Hispanic
# mos_gender                                                       M
# mos_age_incident                                                32
# complainant_ethnicity                                        Black
# complainant_gender                                          Female
# complainant_age_incident                                        38
# fado_type                                       Abuse of Authority
# allegation                            Failure to provide RTKA card
# precinct                                                        78
# contact_reason                             Report-domestic dispute
# outcome_description               No arrest made or summons issued
# board_disposition         Substantiated (Command Lvl Instructions)
#
#                                                         1  \
# unique_mos_id                                       10007
# command_now                                       078 PCT
# complaint_id                                        24601
# month_received                                         11
# year_received                                        2011
# month_closed                                            8
# year_closed                                          2012
# command_at_incident                                  PBBS
# rank_abbrev_incident                                  POM
# rank_abbrev_now                                       POM
# mos_ethnicity                                       White
# mos_gender                                              M
# mos_age_incident                                       24
# complainant_ethnicity                               Black
# complainant_gender                                   Male
# complainant_age_incident                               26
# fado_type                                     Discourtesy
# allegation                                         Action
# precinct                                               67
# contact_reason                           Moving violation
# outcome_description       Moving violation summons issued
# board_disposition                 Substantiated (Charges)
#
#                                                         2  \
# unique_mos_id                                       10007
# command_now                                       078 PCT
# complaint_id                                        24601
# month_received                                         11
# year_received                                        2011
# month_closed                                            8
# year_closed                                          2012
# command_at_incident                                  PBBS
# rank_abbrev_incident                                  POM
# rank_abbrev_now                                       POM
# mos_ethnicity                                       White
# mos_gender                                              M
# mos_age_incident                                       24
# complainant_ethnicity                               Black
# complainant_gender                                   Male
# complainant_age_incident                               26
# fado_type                              Offensive Language
# allegation                                           Race
# precinct                                               67
# contact_reason                           Moving violation
# outcome_description       Moving violation summons issued
# board_disposition                 Substantiated (Charges)
#
#                                                                      3  \
# unique_mos_id                                                    10007
# command_now                                                    078 PCT
# complaint_id                                                     26146
# month_received                                                       7
# year_received                                                     2012
# month_closed                                                         9
# year_closed                                                       2013
# command_at_incident                                               PBBS
# rank_abbrev_incident                                               POM
# rank_abbrev_now                                                    POM
# mos_ethnicity                                                    White
# mos_gender                                                           M
# mos_age_incident                                                    25
# complainant_ethnicity                                            Black
# complainant_gender                                                Male
# complainant_age_incident                                            45
# fado_type                                           Abuse of Authority
# allegation                                                    Question
# precinct                                                            67
# contact_reason            PD suspected C/V of violation/crime - street
# outcome_description                   No arrest made or summons issued
# board_disposition                              Substantiated (Charges)
#
#                                                              4
# unique_mos_id                                            10009
# command_now                                            078 PCT
# complaint_id                                             40253
# month_received                                               8
# year_received                                             2018
# month_closed                                                 2
# year_closed                                               2019
# command_at_incident                                    078 PCT
# rank_abbrev_incident                                       POF
# rank_abbrev_now                                            POF
# mos_ethnicity                                         Hispanic
# mos_gender                                                   F
# mos_age_incident                                            39
# complainant_ethnicity                                      NaN
# complainant_gender                                         NaN
# complainant_age_incident                                    16
# fado_type                                                Force
# allegation                                      Physical force
# precinct                                                    67
# contact_reason                                  Report-dispute
# outcome_description             Arrest - other violation/crime
# board_disposition         Substantiated (Command Discipline A)

# %%
# check for duplicates 
df.duplicated().sum()
# Out:
# 631

# %%
# Remove duplicate rows 
print(f'Shape before removing duplicates: {df.shape}')
df.drop_duplicates(inplace=True)
# Sanity check 
print(f'Num duplicates remaining: {df.duplicated().sum()}')
print(f'Shape after removing duplicates: {df.shape}')
# Out:
# Shape before removing duplicates: (33358, 22)
# Num duplicates remaining: 0
# Shape after removing duplicates: (32727, 22)

# %%
# Sort df by date 
df.sort_values(by=['year_received', 'month_received'], inplace=True, ascending=True)

# %%
# Sanity check 
df.head().T
# Out:
#                                                      5804   \
# unique_mos_id                                        17403
# command_now                                        CD OP/D
# complaint_id                                           517
# month_received                                           9
# year_received                                         1985
# month_closed                                             9
# year_closed                                           1985
# command_at_incident                                    NaN
# rank_abbrev_incident                                   POM
# rank_abbrev_now                                         DC
# mos_ethnicity                                        White
# mos_gender                                               M
# mos_age_incident                                        25
# complainant_ethnicity                                  NaN
# complainant_gender                                     NaN
# complainant_age_incident                               NaN
# fado_type                                      Discourtesy
# allegation                                           Curse
# precinct                                                83
# contact_reason                Report of Crime Past/Present
# outcome_description       No arrest made or summons issued
# board_disposition                          Unsubstantiated
#
#                                                      5805   \
# unique_mos_id                                        17403
# command_now                                        CD OP/D
# complaint_id                                           517
# month_received                                           9
# year_received                                         1985
# month_closed                                             9
# year_closed                                           1985
# command_at_incident                                    NaN
# rank_abbrev_incident                                   POM
# rank_abbrev_now                                         DC
# mos_ethnicity                                        White
# mos_gender                                               M
# mos_age_incident                                        25
# complainant_ethnicity                                  NaN
# complainant_gender                                     NaN
# complainant_age_incident                               NaN
# fado_type                                            Force
# allegation                                      Push/Shove
# precinct                                                83
# contact_reason                Report of Crime Past/Present
# outcome_description       No arrest made or summons issued
# board_disposition                          Unsubstantiated
#
#                                                      5806   \
# unique_mos_id                                        17403
# command_now                                        CD OP/D
# complaint_id                                           517
# month_received                                           9
# year_received                                         1985
# month_closed                                             9
# year_closed                                           1985
# command_at_incident                                    NaN
# rank_abbrev_incident                                   POM
# rank_abbrev_now                                         DC
# mos_ethnicity                                        White
# mos_gender                                               M
# mos_age_incident                                        25
# complainant_ethnicity                                  NaN
# complainant_gender                                     NaN
# complainant_age_incident                               NaN
# fado_type                               Abuse of Authority
# allegation                                 Arrest/D. A. T.
# precinct                                                83
# contact_reason                Report of Crime Past/Present
# outcome_description       No arrest made or summons issued
# board_disposition                          Unsubstantiated
#
#                                                        7967   \
# unique_mos_id                                          18770
# command_now                                           DB CID
# complaint_id                                             528
# month_received                                            10
# year_received                                           1985
# month_closed                                              10
# year_closed                                             1985
# command_at_incident                                      NaN
# rank_abbrev_incident                                     POM
# rank_abbrev_now                                          DT2
# mos_ethnicity                                          White
# mos_gender                                                 M
# mos_age_incident                                          23
# complainant_ethnicity                                    NaN
# complainant_gender                                       NaN
# complainant_age_incident                                 NaN
# fado_type                                              Force
# allegation                                        Punch/Kick
# precinct                                                  63
# contact_reason                                       Dispute
# outcome_description         No arrest made or summons issued
# board_disposition         Substantiated (Command Discipline)
#
#                                                      10891
# unique_mos_id                                        20619
# command_now                                        FAM SEC
# complaint_id                                           525
# month_received                                          10
# year_received                                         1985
# month_closed                                            10
# year_closed                                           1985
# command_at_incident                                    NaN
# rank_abbrev_incident                                   POM
# rank_abbrev_now                                        DTS
# mos_ethnicity                                        Black
# mos_gender                                               M
# mos_age_incident                                        23
# complainant_ethnicity                                  NaN
# complainant_gender                                     NaN
# complainant_age_incident                               NaN
# fado_type                                            Force
# allegation                                  Dragged/Pulled
# precinct                                                71
# contact_reason                Report of Crime Past/Present
# outcome_description       No arrest made or summons issued
# board_disposition                          Unsubstantiated

# %%
df['board_disposition'].value_counts()
# Out:
# Unsubstantiated                             15085
# Exonerated                                   9484
# Substantiated (Charges)                      3727
# Substantiated (Formalized Training)          1014
# Substantiated (Command Discipline A)          947
# Substantiated (Command Discipline)            843
# Substantiated (Command Discipline B)          771
# Substantiated (Command Lvl Instructions)      445
# Substantiated (Instructions)                  245
# Substantiated (No Recommendations)            165
# Substantiated (MOS Unidentified)                1
# Name: board_disposition, dtype: int64

# %%
# create column for unsub/exonerated 
condition = (df['board_disposition']=='Unsubstantiated') | (df['board_disposition']=='Exonerated')
df['unsubst_or_exonerated'] = np.where(condition, 1, 0)

# %%
df.head().T
# Out:
#                                                      5804   \
# unique_mos_id                                        17403
# command_now                                        CD OP/D
# complaint_id                                           517
# month_received                                           9
# year_received                                         1985
# month_closed                                             9
# year_closed                                           1985
# command_at_incident                                    NaN
# rank_abbrev_incident                                   POM
# rank_abbrev_now                                         DC
# mos_ethnicity                                        White
# mos_gender                                               M
# mos_age_incident                                        25
# complainant_ethnicity                                  NaN
# complainant_gender                                     NaN
# complainant_age_incident                               NaN
# fado_type                                      Discourtesy
# allegation                                           Curse
# precinct                                                83
# contact_reason                Report of Crime Past/Present
# outcome_description       No arrest made or summons issued
# board_disposition                          Unsubstantiated
# unsubst_or_exonerated                                    1
#
#                                                      5805   \
# unique_mos_id                                        17403
# command_now                                        CD OP/D
# complaint_id                                           517
# month_received                                           9
# year_received                                         1985
# month_closed                                             9
# year_closed                                           1985
# command_at_incident                                    NaN
# rank_abbrev_incident                                   POM
# rank_abbrev_now                                         DC
# mos_ethnicity                                        White
# mos_gender                                               M
# mos_age_incident                                        25
# complainant_ethnicity                                  NaN
# complainant_gender                                     NaN
# complainant_age_incident                               NaN
# fado_type                                            Force
# allegation                                      Push/Shove
# precinct                                                83
# contact_reason                Report of Crime Past/Present
# outcome_description       No arrest made or summons issued
# board_disposition                          Unsubstantiated
# unsubst_or_exonerated                                    1
#
#                                                      5806   \
# unique_mos_id                                        17403
# command_now                                        CD OP/D
# complaint_id                                           517
# month_received                                           9
# year_received                                         1985
# month_closed                                             9
# year_closed                                           1985
# command_at_incident                                    NaN
# rank_abbrev_incident                                   POM
# rank_abbrev_now                                         DC
# mos_ethnicity                                        White
# mos_gender                                               M
# mos_age_incident                                        25
# complainant_ethnicity                                  NaN
# complainant_gender                                     NaN
# complainant_age_incident                               NaN
# fado_type                               Abuse of Authority
# allegation                                 Arrest/D. A. T.
# precinct                                                83
# contact_reason                Report of Crime Past/Present
# outcome_description       No arrest made or summons issued
# board_disposition                          Unsubstantiated
# unsubst_or_exonerated                                    1
#
#                                                        7967   \
# unique_mos_id                                          18770
# command_now                                           DB CID
# complaint_id                                             528
# month_received                                            10
# year_received                                           1985
# month_closed                                              10
# year_closed                                             1985
# command_at_incident                                      NaN
# rank_abbrev_incident                                     POM
# rank_abbrev_now                                          DT2
# mos_ethnicity                                          White
# mos_gender                                                 M
# mos_age_incident                                          23
# complainant_ethnicity                                    NaN
# complainant_gender                                       NaN
# complainant_age_incident                                 NaN
# fado_type                                              Force
# allegation                                        Punch/Kick
# precinct                                                  63
# contact_reason                                       Dispute
# outcome_description         No arrest made or summons issued
# board_disposition         Substantiated (Command Discipline)
# unsubst_or_exonerated                                      0
#
#                                                      10891
# unique_mos_id                                        20619
# command_now                                        FAM SEC
# complaint_id                                           525
# month_received                                          10
# year_received                                         1985
# month_closed                                            10
# year_closed                                           1985
# command_at_incident                                    NaN
# rank_abbrev_incident                                   POM
# rank_abbrev_now                                        DTS
# mos_ethnicity                                        Black
# mos_gender                                               M
# mos_age_incident                                        23
# complainant_ethnicity                                  NaN
# complainant_gender                                     NaN
# complainant_age_incident                               NaN
# fado_type                                            Force
# allegation                                  Dragged/Pulled
# precinct                                                71
# contact_reason                Report of Crime Past/Present
# outcome_description       No arrest made or summons issued
# board_disposition                          Unsubstantiated
# unsubst_or_exonerated                                    1

# %% [markdown]
# ## Split our data into training and testing sets.
# The data will be split based on date.

# %%
# Build a dataframe with the years and how many times they occur in the complaints df
year_val_counts = df['year_received'].value_counts()
df_year_val_counts = pd.DataFrame(year_val_counts)
df_year_val_counts = df_year_val_counts.reset_index()
df_year_val_counts.columns = ['year', 'count']
df_year_val_counts.sort_values(by=['year'], ascending=True, inplace=True)

# %%
df_year_val_counts
# Out:
#     year  count
# 34  1985      7
# 32  1986     19
# 33  1987     16
# 31  1988     32
# 30  1989     37
# 29  1990     39
# 28  1991     41
# 27  1992     67
# 26  1993     67
# 25  1994    153
# 22  1995    204
# 21  1996    225
# 23  1997    198
# 19  1998    237
# 24  1999    155
# 20  2000    228
# 18  2001    342
# 17  2002    565
# 16  2003    781
# 15  2004    958
# 14  2005   1336
# 11  2006   1641
# 7   2007   1884
# 12  2008   1623
# 9   2009   1759
# 10  2010   1652
# 6   2011   1884
# 8   2012   1833
# 4   2013   2108
# 3   2014   2195
# 0   2015   2276
# 1   2016   2265
# 5   2017   2092
# 2   2018   2199
# 13  2019   1605
# 35  2020      4

# %%
df_year_val_counts['count'].sum()
# Out:
# 32727

# %% [markdown]
# ## Given data distribution, will create a split the data at 2016
# All complaints starting 2017 will be reserved for test data set.

# %%
# Create a dataframe with training data
df_train = df[df['year_received'] < 2017]
df_test = df[df['year_received'] > 2016]

# %%
# Sanity checks 
df_train.head()
# Out:
#        unique_mos_id command_now  complaint_id  month_received  year_received  \
# 5804           17403     CD OP/D           517               9           1985
# 5805           17403     CD OP/D           517               9           1985
# 5806           17403     CD OP/D           517               9           1985
# 7967           18770      DB CID           528              10           1985
# 10891          20619     FAM SEC           525              10           1985
#
#        month_closed  year_closed command_at_incident rank_abbrev_incident  \
# 5804              9         1985                 NaN                  POM
# 5805              9         1985                 NaN                  POM
# 5806              9         1985                 NaN                  POM
# 7967             10         1985                 NaN                  POM
# 10891            10         1985                 NaN                  POM
#
#       rank_abbrev_now mos_ethnicity mos_gender  mos_age_incident  \
# 5804               DC         White          M                25
# 5805               DC         White          M                25
# 5806               DC         White          M                25
# 7967              DT2         White          M                23
# 10891             DTS         Black          M                23
#
#       complainant_ethnicity complainant_gender  complainant_age_incident  \
# 5804                    NaN                NaN                       NaN
# 5805                    NaN                NaN                       NaN
# 5806                    NaN                NaN                       NaN
# 7967                    NaN                NaN                       NaN
# 10891                   NaN                NaN                       NaN
#
#                 fado_type       allegation  precinct  \
# 5804          Discourtesy            Curse      83.0
# 5805                Force       Push/Shove      83.0
# 5806   Abuse of Authority  Arrest/D. A. T.      83.0
# 7967                Force       Punch/Kick      63.0
# 10891               Force   Dragged/Pulled      71.0
#
#                      contact_reason               outcome_description  \
# 5804   Report of Crime Past/Present  No arrest made or summons issued
# 5805   Report of Crime Past/Present  No arrest made or summons issued
# 5806   Report of Crime Past/Present  No arrest made or summons issued
# 7967                        Dispute  No arrest made or summons issued
# 10891  Report of Crime Past/Present  No arrest made or summons issued
#
#                         board_disposition  unsubst_or_exonerated
# 5804                      Unsubstantiated                      1
# 5805                      Unsubstantiated                      1
# 5806                      Unsubstantiated                      1
# 7967   Substantiated (Command Discipline)                      0
# 10891                     Unsubstantiated                      1

# %%
print(f'Earliest year in training dataframe: {df_train["year_received"].min()} \nLatest year in training dataframe: {df_train["year_received"].max()}')
print(f'Earliest year in testing dataframe: {df_test["year_received"].min()} \nLatest year in testing dataframe: {df_test["year_received"].max()}')
# Out:
# Earliest year in training dataframe: 1985
# Latest year in training dataframe: 2016
# Earliest year in testing dataframe: 2017
# Latest year in testing dataframe: 2020

# %%
print(f'Training dataframe shape: {df_train.shape} \nTesting dataframe shape: {df_test.shape}')
# make sure dataframe samples add up to the total of the original dataframe
print(df_train.shape[0]+df_test.shape[0]==df.shape[0])
# Out:
# Training dataframe shape: (26827, 23)
# Testing dataframe shape: (5900, 23)
# True

# %% [markdown]
# ## Transform and prep data in each dataframe for modeling

# %%
# Check datatypes 
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26827 entries, 5804 to 33344
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             26827 non-null  int64
#  1   command_now               26827 non-null  object
#  2   complaint_id              26827 non-null  int64
#  3   month_received            26827 non-null  int64
#  4   year_received             26827 non-null  int64
#  5   month_closed              26827 non-null  int64
#  6   year_closed               26827 non-null  int64
#  7   command_at_incident       25450 non-null  object
#  8   rank_abbrev_incident      26827 non-null  object
#  9   rank_abbrev_now           26827 non-null  object
#  10  mos_ethnicity             26827 non-null  object
#  11  mos_gender                26827 non-null  object
#  12  mos_age_incident          26827 non-null  int64
#  13  complainant_ethnicity     23337 non-null  object
#  14  complainant_gender        23524 non-null  object
#  15  complainant_age_incident  23035 non-null  float64
#  16  fado_type                 26827 non-null  object
#  17  allegation                26826 non-null  object
#  18  precinct                  26814 non-null  float64
#  19  contact_reason            26687 non-null  object
#  20  outcome_description       26820 non-null  object
#  21  board_disposition         26827 non-null  object
#  22  unsubst_or_exonerated     26827 non-null  int64
# dtypes: float64(2), int64(8), object(13)
# memory usage: 4.9+ MB

# %%
# check for null values 
df_train.isna().sum()
# Out:
# unique_mos_id                  0
# command_now                    0
# complaint_id                   0
# month_received                 0
# year_received                  0
# month_closed                   0
# year_closed                    0
# command_at_incident         1377
# rank_abbrev_incident           0
# rank_abbrev_now                0
# mos_ethnicity                  0
# mos_gender                     0
# mos_age_incident               0
# complainant_ethnicity       3490
# complainant_gender          3303
# complainant_age_incident    3792
# fado_type                      0
# allegation                     1
# precinct                      13
# contact_reason               140
# outcome_description            7
# board_disposition              0
# unsubst_or_exonerated          0
# dtype: int64

# %%
df_train['complainant_age_incident'].value_counts()
# Out:
#  26.0      903
#  24.0      901
#  30.0      868
#  23.0      851
#  25.0      849
#           ...
#  87.0        1
# -4301.0      1
#  7.0         1
#  88.0        1
#  83.0        1
# Name: complainant_age_incident, Length: 88, dtype: int64

# %%
def prep_data(df):
    """
    Transforms data to suit modeling needs. Returns df. 
    """
    # Fill null values in numeric rows with median to avoid impact of outliers 
    for label, content in df.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                # Add a column to indicate if data was missing
                df[label+"_is_missing"] = pd.isnull(content)
                # Fill missing numeric values with median
                df[label] = content.fillna(content.median())
    
        # Turn object/string rows into categories 
        if not pd.api.types.is_numeric_dtype(content):
            # Column to indicate if data was missing
            df[label+"_is_missing"] = pd.isnull(content)
            # add +1 to the category code because pandas encodes missing vals with -1
            # This way NaN values will be codes as 1 
            df[label] = pd.Categorical(content).codes+1
    
    return df

# %%
# Use prep_data function to categories and fill NaN vals in training df
df_train = prep_data(df_train)

# %%
# Use prep_data function to categories and fill NaN vals in testing df
df_test = prep_data(df_test)

# %% [markdown]
# ## Create and evaluate random forest classification model

# %%
df_train.head().T
# Out:
#                                      5804   5805   5806   7967   10891
# unique_mos_id                        17403  17403  17403  18770  20619
# command_now                            169    169    169    192    248
# complaint_id                           517    517    517    528    525
# month_received                           9      9      9     10     10
# year_received                         1985   1985   1985   1985   1985
# month_closed                             9      9      9     10     10
# year_closed                           1985   1985   1985   1985   1985
# command_at_incident                      0      0      0      0      0
# rank_abbrev_incident                    15     15     15     15     15
# rank_abbrev_now                          6      6      6      9     11
# mos_ethnicity                            5      5      5      5      3
# mos_gender                               2      2      2      2      2
# mos_age_incident                        25     25     25     23     23
# complainant_ethnicity                    0      0      0      0      0
# complainant_gender                       0      0      0      0      0
# complainant_age_incident                30     30     30     30     30
# fado_type                                2      3      1      3      3
# allegation                               8     60      3     59     11
# precinct                                83     83     83     63     71
# contact_reason                          37     37     37     18     37
# outcome_description                     13     13     13     13     13
# board_disposition                       11     11     11      5     11
# unsubst_or_exonerated                    1      1      1      0      1
# command_now_is_missing               False  False  False  False  False
# command_at_incident_is_missing        True   True   True   True   True
# rank_abbrev_incident_is_missing      False  False  False  False  False
# rank_abbrev_now_is_missing           False  False  False  False  False
# mos_ethnicity_is_missing             False  False  False  False  False
# mos_gender_is_missing                False  False  False  False  False
# complainant_ethnicity_is_missing      True   True   True   True   True
# complainant_gender_is_missing         True   True   True   True   True
# complainant_age_incident_is_missing   True   True   True   True   True
# fado_type_is_missing                 False  False  False  False  False
# allegation_is_missing                False  False  False  False  False
# precinct_is_missing                  False  False  False  False  False
# contact_reason_is_missing            False  False  False  False  False
# outcome_description_is_missing       False  False  False  False  False
# board_disposition_is_missing         False  False  False  False  False

# %%
X_train, y_train = df_train.drop(['outcome_description', 'board_disposition', 'unsubst_or_exonerated'], axis=1), df_train['unsubst_or_exonerated']
X_test, y_test = df_test.drop(['outcome_description', 'board_disposition', 'unsubst_or_exonerated'], axis=1), df_test['unsubst_or_exonerated']

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((26827, 35), (26827,), (5900, 35), (5900,))

# %%
def evaluate_class_model(model): 
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_true=y_test, y_pred=y_pred, )
    print("Accuracy Score: %f" % accuracy)

    precision = precision_score(y_true=y_test, y_pred=y_pred, average='micro')
    print("Precision Score: %f" % precision)

    recall = recall_score(y_true=y_test, y_pred=y_pred, average='micro')
    print("Recall Score: %f" % recall)

    f1 = f1_score(y_true=y_test, y_pred=y_pred, average='micro')
    print('F1 Score: %f' % f1)

    # Calculate predicted probabilities, keep only probability for when class = 1
#     y_pred_proba = model.predict_proba(X_test)[:,1]
#     auc = roc_auc_score(y_true=y_test, y_score=y_pred_proba, multi_class='ovo')
#     print(f'AUC Score: %f' % auc)

# %%
model = RandomForestClassifier(n_estimators=20, criterion='gini', max_features=25, 
                              min_samples_split=2, max_depth=100)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=100, max_features=25, n_estimators=20)

# %%
evaluate_class_model(model)
# Out:
# Accuracy Score: 0.615593
# Precision Score: 0.615593
# Recall Score: 0.615593
# F1 Score: 0.615593

# %%
params= {'criterion': ['gini', 'entropy'], 
         'max_depth': [2, 4, 5, 10, 20, 100], 
         'max_features': [2, 5, 10, 15, 25, 'auto'], 
         'min_samples_split': [2, 10, 20, 100], 
         'n_estimators': [2, 5, 10, 20, 100],
         }


grid_search_cv =  GridSearchCV( 
    estimator=RandomForestClassifier(), 
    param_grid = params, 
    scoring = 'f1'
    )

# %%
grid_search_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 5, 10, 20, 100],
#                          'max_features': [2, 5, 10, 15, 25, 'auto'],
#                          'min_samples_split': [2, 10, 20, 100],
#                          'n_estimators': [2, 5, 10, 20, 100]},
#              scoring='f1')

# %%
print(grid_search_cv.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_split': 100, 'n_estimators': 10}

# %%
model = grid_search_cv.best_estimator_
evaluate_class_model(model)
# Out:
# Accuracy Score: 0.718644
# Precision Score: 0.718644
# Recall Score: 0.718644
# F1 Score: 0.718644

# %%
# check feature importance 
selected_features = list(df_train.drop(['outcome_description', 'board_disposition', 'unsubst_or_exonerated'], axis=1))
feature_imp = pd.DataFrame.from_dict( {'feature_importance': model.feature_importances_,
                                       'feature':selected_features }).sort_values('feature_importance', ascending=False)
feature_imp
# Out:
#     feature_importance                              feature
# 16            0.276387                            fado_type
# 17            0.140803                           allegation
# 11            0.113405                           mos_gender
# 6             0.111333                          year_closed
# 4             0.071517                        year_received
# 14            0.056398                   complainant_gender
# 7             0.050680                  command_at_incident
# 9             0.044503                      rank_abbrev_now
# 0             0.033355                        unique_mos_id
# 10            0.032833                        mos_ethnicity
# 18            0.030377                             precinct
# 19            0.022521                       contact_reason
# 15            0.014786             complainant_age_incident
# 12            0.001102                     mos_age_incident
# 8             0.000000                 rank_abbrev_incident
# 25            0.000000                mos_gender_is_missing
# 33            0.000000       outcome_description_is_missing
# 32            0.000000            contact_reason_is_missing
# 31            0.000000                  precinct_is_missing
# 30            0.000000                allegation_is_missing
# 29            0.000000                 fado_type_is_missing
# 28            0.000000  complainant_age_incident_is_missing
# 27            0.000000        complainant_gender_is_missing
# 26            0.000000     complainant_ethnicity_is_missing
# 22            0.000000      rank_abbrev_incident_is_missing
# 24            0.000000             mos_ethnicity_is_missing
# 23            0.000000           rank_abbrev_now_is_missing
# 21            0.000000       command_at_incident_is_missing
# 20            0.000000               command_now_is_missing
# 1             0.000000                          command_now
# 2             0.000000                         complaint_id
# 3             0.000000                       month_received
# 13            0.000000                complainant_ethnicity
# 5             0.000000                         month_closed
# 34            0.000000         board_disposition_is_missing

# %%
import pickle
# Dump the trained decision tree classifier with Pickle
filename = 'rf_classifier.pkl'
# Open the file to save as pkl file
pickle.dump(model, open(filename, 'wb'))
